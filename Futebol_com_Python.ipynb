# %% [markdown]
# <a href="https://colab.research.google.com/github/julianosfreitas/Analise-de-Dados/blob/main/Futebol_com_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 💽BIBLIOTECA

# %%
# Pandas -> usada principalmente para manipulação e análise de dados.
import pandas as pd

# %% [markdown]
# ## 🧮 LEITURA DADOS

# %%
# Escolher o tipo de arquivo para poder fazer a extração dos dados.

# pd.read_csv() #CSV
# pd.read_excel() #EXCEL
# pd.read_json() #JSON
# pd.read_html #HTML

# %%
dados = pd.read_csv('/content/dados_time.csv', sep = ';')

# %% [markdown]
# ## 🧵Explorar e Tratar Dados

# %% [markdown]
# ### HEAD ( )

# %%
# Aparecer a tabela que foi chamada em cima por *dados* *os 10 primeiros -> (10)*
dados.head(10)
# Out:
#       Nome     Posição  Titular  Nª Partida Time Adversário  Vitória  Gols  \
# 0   Ivarov     Goleiro     True           1       Titã F.C.    False     0
# 1  Stromer    Zagueiro     True           1       Titã F.C.    False     0
# 2    Dulic    Zagueiro     True           1       Titã F.C.    False     0
# 3   Valeny     Lateral     True           1       Titã F.C.    False     0
# 4    Iouga     Lateral     True           1       Titã F.C.    False     0
# 5  Celnili     Volante     True           1       Titã F.C.    False     0
# 6  Ximelez     Volante     True           1       Titã F.C.    False     0
# 7  Espimas  Meio campo     True           1       Titã F.C.    False     0
# 8  Minanda  Meio campo     True           1       Titã F.C.    False     1
# 9  Castolo    Atacante     True           1       Titã F.C.    False     0
#
#    Assistências  Desarmes  Desarmado  ...  Cartão Vermelho  Passes certos  \
# ...

# %% [markdown]
# # 📏SHAPE

# %%
# Mostra a quantidade de |LINHAS e COLUNAS|
dados.shape
# Out:
# (240, 21)

# %% [markdown]
# ## 🧮INFO ( )

# %%
# Vai mostrar as informações em forma de TABELA
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Nome             240 non-null    object
#  1   Posição          240 non-null    object
#  2   Titular          240 non-null    bool
#  3   Nª Partida       240 non-null    int64
#  4   Time Adversário  240 non-null    object
#  5   Vitória          240 non-null    bool
#  6   Gols             240 non-null    int64
#  7   Assistências     240 non-null    int64
#  8   Desarmes         121 non-null    float64
#  9   Desarmado        93 non-null     float64
#  10  Cartão Amarelo   240 non-null    int64
#  11  Cartão Vermelho  240 non-null    int64
#  12  Passes certos    166 non-null    float64
#  13  Passes errados   146 non-null    float64
#  14  Chutes a gol     53 non-null     float64
#  15  Tempo em Campo   240 non-null    int64
#  16  Lesão            240 non-null    bool
# ...

# %%
# DROP serve para remover linhas ou colunas manualmente.
# nome_tabela.drop(nome_da_coluna = ['culuna_para_deletar'], axis = 0_ou_1)
# AXIS = 0 -> LINHAS
# AXIS = 1 -> COLUNAS

dados.drop(columns = ['Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20'], axis = 1)
# Out:
#         Nome     Posição  Titular  Nª Partida Time Adversário  Vitória  Gols  \
# 0     Ivarov     Goleiro     True           1       Titã F.C.    False     0
# 1    Stromer    Zagueiro     True           1       Titã F.C.    False     0
# 2      Dulic    Zagueiro     True           1       Titã F.C.    False     0
# 3     Valeny     Lateral     True           1       Titã F.C.    False     0
# 4      Iouga     Lateral     True           1       Titã F.C.    False     0
# ..       ...         ...      ...         ...             ...      ...   ...
# 235   Barota    Atacante     True          16     Portal F.C.    False     0
# 236    Ceciu    Zagueiro     True          16     Portal F.C.    False     0
# 237    Harty     Volante    False          16     Portal F.C.    False     0
# 238  Ostwaut  Meio campo    False          16     Portal F.C.    False     0
# 239  Huylens    Atacante    False          16     Portal F.C.    False     0
#
# ...

# %% [markdown]
#  Depois se formos checar, não houve alteração

# %%
dados.head()
# Out:
#       Nome   Posição  Titular  Nª Partida Time Adversário  Vitória  Gols  \
# 0   Ivarov   Goleiro     True           1       Titã F.C.    False     0
# 1  Stromer  Zagueiro     True           1       Titã F.C.    False     0
# 2    Dulic  Zagueiro     True           1       Titã F.C.    False     0
# 3   Valeny   Lateral     True           1       Titã F.C.    False     0
# 4    Iouga   Lateral     True           1       Titã F.C.    False     0
#
#    Assistências  Desarmes  Desarmado  ...  Cartão Vermelho  Passes certos  \
# 0             0       NaN        NaN  ...                0            2.0
# 1             0       6.0        NaN  ...                1            4.0
# 2             0       2.0        NaN  ...                0            6.0
# 3             0       NaN        NaN  ...                0            6.0
# 4             0       3.0        NaN  ...                0            6.0
#
#    Passes errados  Chutes a gol  Tempo em Campo  Lesão  Unnamed: 17  \
# ...

# %% [markdown]
# 1.Reatibuir à mesma variável ou usar **inplace = true**.
#
# 2.Para criar uma tabela com nome de variável diferente para manteer a tabela original intacta.

# %%
colunas = ['Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20']

# %%
dados = dados.drop(columns = colunas, axis = 1)
# ou  dados.drop(columns = colunas, axis = 1, inplace = True)

# %%
dados.columns
# Out:
# Index(['Nome', 'Posição', 'Titular', 'Nª Partida', 'Time Adversário',
#        'Vitória', 'Gols', 'Assistências', 'Desarmes', 'Desarmado',
#        'Cartão Amarelo', 'Cartão Vermelho', 'Passes certos', 'Passes errados',
#        'Chutes a gol', 'Tempo em Campo', 'Lesão'],
#       dtype='object')

# %%
dados.head(10)
# Out:
#       Nome     Posição  Titular  Nª Partida Time Adversário  Vitória  Gols  \
# 0   Ivarov     Goleiro     True           1       Titã F.C.    False     0
# 1  Stromer    Zagueiro     True           1       Titã F.C.    False     0
# 2    Dulic    Zagueiro     True           1       Titã F.C.    False     0
# 3   Valeny     Lateral     True           1       Titã F.C.    False     0
# 4    Iouga     Lateral     True           1       Titã F.C.    False     0
# 5  Celnili     Volante     True           1       Titã F.C.    False     0
# 6  Ximelez     Volante     True           1       Titã F.C.    False     0
# 7  Espimas  Meio campo     True           1       Titã F.C.    False     0
# 8  Minanda  Meio campo     True           1       Titã F.C.    False     1
# 9  Castolo    Atacante     True           1       Titã F.C.    False     0
#
#    Assistências  Desarmes  Desarmado  Cartão Amarelo  Cartão Vermelho  \
# 0             0       NaN        NaN               0                0
# ...

# %% [markdown]
# ## **Σ** DESCRIBE ()
# # <h3>Mostra informações de contagem, média, desvio padrão e quartis para dados numéricos do conjunto de dados.</h3>

# %%
dados.describe(include = 'all')
# Out:
#           Nome   Posição Titular  Nª Partida Time Adversário Vitória  \
# count      240       240     240  240.000000             240     240
# unique      15         6       2         NaN               8       2
# top     Ivarov  Zagueiro    True         NaN       Titã F.C.   False
# freq        16        48     177         NaN              30     120
# mean       NaN       NaN     NaN    8.500000             NaN     NaN
# std        NaN       NaN     NaN    4.619406             NaN     NaN
# min        NaN       NaN     NaN    1.000000             NaN     NaN
# 25%        NaN       NaN     NaN    4.750000             NaN     NaN
# 50%        NaN       NaN     NaN    8.500000             NaN     NaN
# 75%        NaN       NaN     NaN   12.250000             NaN     NaN
# max        NaN       NaN     NaN   16.000000             NaN     NaN
#
#               Gols  Assistências    Desarmes  Desarmado  Cartão Amarelo  \
# ...

# %% [markdown]
# # 🎯FILTROS

# %% [markdown]
# <h3> Podemos selecionar colunas da tabela utilizando os colchonetes e passando o nome da coluna *ou* uma linha ou uma lista da colunas que desejarmos </h3>

# %%
dados['Desarmes']

# %%
dados[['Desarmes']].head(10)

# %%
dados[['Nome', 'Posição', 'Gols']].head(50)

# %%
dados['Posição'] == 'Goleiro'

# %%
dados[dados['Posição'] == 'Goleiro']

# %% [markdown]
# Quando utilizamos as *comparações* da biblioteca *pandas* dessa forma, precisa usar **&** para o operador **and** e **|** para operador **or**.

# %% [markdown]
# Como *filtrar* apenas as **vitórias** dos **goleiros**? 🧤✅
# -> GOLEIROS **E** VITÓRIAS

# %%
dados[(dados['Posição'] == 'Goleiro') & (dados['Vitória']==True)]

# %% [markdown]
# Como *filtrar* apenas os **goleiros** e **zagueiros**? 🧤🛡️
# -> GOLEIROS **OU** ZAGUEIROS

# %%
dados[(dados['Posição'] == 'Goleiro') | (dados['Posição']=='Zagueiro')]

# %% [markdown]
# Como ver os **dados nulos**? ❌ -> função **ISNA ( )**

# %%
dados.isna()

# %%
dados.isna().sum()

# %% [markdown]
#  Como tirar esses **dados nulos**? ❌ **>** ♻️***(Limpeza de dados)***

# %%
colunas = []
for coluna in dados.columns:
  if dados[coluna].isna().sum != 0:
    colunas.append(coluna)
dados[colunas]
# Out:
#         Nome     Posição  Titular  Nª Partida Time Adversário  Vitória  Gols  \
# 0     Ivarov     Goleiro     True           1       Titã F.C.    False     0
# 1    Stromer    Zagueiro     True           1       Titã F.C.    False     0
# 2      Dulic    Zagueiro     True           1       Titã F.C.    False     0
# 3     Valeny     Lateral     True           1       Titã F.C.    False     0
# 4      Iouga     Lateral     True           1       Titã F.C.    False     0
# ..       ...         ...      ...         ...             ...      ...   ...
# 235   Barota    Atacante     True          16     Portal F.C.    False     0
# 236    Ceciu    Zagueiro     True          16     Portal F.C.    False     0
# 237    Harty     Volante    False          16     Portal F.C.    False     0
# 238  Ostwaut  Meio campo    False          16     Portal F.C.    False     0
# 239  Huylens    Atacante    False          16     Portal F.C.    False     0
#
# ...

# %% [markdown]
#  Como modificar esses **dados nulos**? ♻️ **>** ⚗️***(Tratamento de dados)***

# %%
dados.fillna(0, inplace = True)

# %%
dados.isna().sum()
# Out:
# Nome               0
# Posição            0
# Titular            0
# Nª Partida         0
# Time Adversário    0
# Vitória            0
# Gols               0
# Assistências       0
# Desarmes           0
# Desarmado          0
# Cartão Amarelo     0
# Cartão Vermelho    0
# Passes certos      0
# Passes errados     0
# Chutes a gol       0
# Tempo em Campo     0
# Lesão              0
# dtype: int64

# %%
dados['Gols'].mean()
# Out:
# 0.125

# %%
dados[colunas]

# %%
dados[dados['Tempo em Campo'] == 0]
# Out:
#         Nome     Posição  Titular  Nª Partida Time Adversário  Vitória  Gols  \
# 11     Ceciu    Zagueiro    False           1       Titã F.C.    False     0
# 12     Harty     Volante    False           1       Titã F.C.    False     0
# 13   Ostwaut  Meio campo    False           1       Titã F.C.    False     0
# 14   Huylens    Atacante    False           1       Titã F.C.    False     0
# 16   Stromer    Zagueiro    False           2     Brutal E.C.     True     0
# 29   Huylens    Atacante    False           2     Brutal E.C.     True     0
# 41     Ceciu    Zagueiro    False           3     Tucano F.C.    False     0
# 42     Harty     Volante    False           3     Tucano F.C.    False     0
# 43   Ostwaut  Meio campo    False           3     Tucano F.C.    False     0
# 56     Ceciu    Zagueiro    False           4   Tamanduá E.C.     True     0
# 57     Harty     Volante    False           4   Tamanduá E.C.     True     0
# ...

# %%
dados = dados[dados['Tempo em Campo'] != 0]
dados
# Out:
#         Nome     Posição  Titular  Nª Partida Time Adversário  Vitória  Gols  \
# 0     Ivarov     Goleiro     True           1       Titã F.C.    False     0
# 1    Stromer    Zagueiro     True           1       Titã F.C.    False     0
# 2      Dulic    Zagueiro     True           1       Titã F.C.    False     0
# 3     Valeny     Lateral     True           1       Titã F.C.    False     0
# 4      Iouga     Lateral     True           1       Titã F.C.    False     0
# ..       ...         ...      ...         ...             ...      ...   ...
# 232  Espimas  Meio campo     True          16     Portal F.C.    False     0
# 233  Minanda  Meio campo     True          16     Portal F.C.    False     0
# 234  Castolo    Atacante     True          16     Portal F.C.    False     1
# 235   Barota    Atacante     True          16     Portal F.C.    False     0
# 236    Ceciu    Zagueiro     True          16     Portal F.C.    False     0
#
# ...

# %% [markdown]
# # Como **Agrupar** e **Ordenar** os **dados**? 🗃️

# %%
dados.describe(include='all')

# %%
dados.groupby('Nome')

# %%
dados.groupby('Nome').mean()

# %%
soma_dados = dados.groupby('Nome').sum()
soma_dados
# Out:
#                                                    Posição  Titular  \
# Nome
# Barota   AtacanteAtacanteAtacanteAtacanteAtacanteAtacan...       16
# Castolo  AtacanteAtacanteAtacanteAtacanteAtacanteAtacan...       16
# Ceciu                             ZagueiroZagueiroZagueiro        3
# Celnili  VolanteVolanteVolanteVolanteVolanteVolanteVola...       16
# Dulic    ZagueiroZagueiroZagueiroZagueiroZagueiroZaguei...       16
# Espimas  Meio campoMeio campoMeio campoMeio campoMeio c...       16
# Harty                                       VolanteVolante        0
# Huylens                                   AtacanteAtacante        0
# Iouga    LateralLateralLateralLateralLateralLateralLate...       16
# Ivarov   GoleiroGoleiroGoleiroGoleiroGoleiroGoleiroGole...       16
# Minanda  Meio campoMeio campoMeio campoMeio campoMeio c...       14
# Ostwaut           Meio campoMeio campoMeio campoMeio campo        2
# Stromer  ZagueiroZagueiroZagueiroZagueiroZagueiroZaguei...       13
# ...

# %%
soma_dados[['Gols', 'Assistências', 'Passes certos', 'Passes errados', 'Tempo em Campo']]
# Out:
#          Gols  Assistências  Passes certos  Passes errados  Tempo em Campo
# Nome
# Barota      5             2           47.0            27.0            1345
# Castolo    11             3           54.0            28.0            1440
# Ceciu       0             0            7.0             5.0             270
# Celnili     0             2          144.0            64.0            1385
# Dulic       0             1           49.0            32.0            1440
# Espimas     4             5          190.0            64.0            1440
# Harty       1             0            2.0             1.0              55
# Huylens     1             0            5.0             2.0              95
# Iouga       1             1          135.0            32.0            1440
# Ivarov      0             0            8.0             0.0            1440
# Minanda     2             1          146.0            80.0            1170
# ...

# %% [markdown]
# # Como saber o atleta que fez **menos gols** ou **mais gols**? ⚽

# %%
soma_dados[['Gols', 'Assistências', 'Passes certos', 'Passes errados', 'Tempo em Campo']].sort_values('Gols')
# Out:
#          Gols  Assistências  Passes certos  Passes errados  Tempo em Campo
# Nome
# Ceciu       0             0            7.0             5.0             270
# Celnili     0             2          144.0            64.0            1385
# Dulic       0             1           49.0            32.0            1440
# Ivarov      0             0            8.0             0.0            1440
# Harty       1             0            2.0             1.0              55
# Huylens     1             0            5.0             2.0              95
# Iouga       1             1          135.0            32.0            1440
# Ostwaut     1             1           18.0             5.0             240
# Stromer     1             0           45.0            32.0            1127
# Ximelez     1             1          124.0            52.0            1440
# Minanda     2             1          146.0            80.0            1170
# ...

# %%
soma_dados[['Gols', 'Assistências', 'Passes certos', 'Passes errados', 'Tempo em Campo']].sort_values('Gols', ascending = False)
# Out:
#          Gols  Assistências  Passes certos  Passes errados  Tempo em Campo
# Nome
# Castolo    11             3           54.0            28.0            1440
# Barota      5             2           47.0            27.0            1345
# Espimas     4             5          190.0            64.0            1440
# Minanda     2             1          146.0            80.0            1170
# Valeny      2             0           80.0            46.0            1440
# Harty       1             0            2.0             1.0              55
# Huylens     1             0            5.0             2.0              95
# Iouga       1             1          135.0            32.0            1440
# Ostwaut     1             1           18.0             5.0             240
# Stromer     1             0           45.0            32.0            1127
# Ximelez     1             1          124.0            52.0            1440
# ...

# %%
soma_dados[['Gols', 'Assistências', 'Passes certos', 'Passes errados', 'Tempo em Campo']].sort_values(['Gols', 'Tempo em Campo'], ascending=False)
# Out:
#          Gols  Assistências  Passes certos  Passes errados  Tempo em Campo
# Nome
# Castolo    11             3           54.0            28.0            1440
# Barota      5             2           47.0            27.0            1345
# Espimas     4             5          190.0            64.0            1440
# Valeny      2             0           80.0            46.0            1440
# Minanda     2             1          146.0            80.0            1170
# Iouga       1             1          135.0            32.0            1440
# Ximelez     1             1          124.0            52.0            1440
# Stromer     1             0           45.0            32.0            1127
# Ostwaut     1             1           18.0             5.0             240
# Huylens     1             0            5.0             2.0              95
# Harty       1             0            2.0             1.0              55
# ...

# %% [markdown]
# # SALVAR DADOS 💾

# %%
dados.to_csv('dados_tratados.csv', index = False)
